# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as pdr

# %%
stock_ticker = 'SPY'
start_date, stop_date = '2018-01-01', '2018-12-31'
data = pdr.get_data_yahoo(stock_ticker, start_date, stop_date)
stock_data = data.values

highs = stock_data[:,0]
lows = stock_data[:,1]
opening = stock_data[:,2]
closing = stock_data[:,3]
volume = stock_data[:,4]
adjusted_close = stock_data[:,5]

trading_days = np.linspace(0,len(highs) - 1, len(highs))

# %%
def traderBot(ticker, start_date, stop_date):
    data = pdr.get_data_yahoo(ticker, start_date, stop_date)
    stock_data = data.values
    highs = stock_data[:,0]
    lows = stock_data[:,1]
    opening = stock_data[:,2]
    closing = stock_data[:,3]
    volume = stock_data[:,4]
    adjusted_close = stock_data[:,5]

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
ax1.plot(trading_days, closing, label='Closing Values')
ax1.set_ylabel('Value [USD]')

ax1.legend()
plt.show()
